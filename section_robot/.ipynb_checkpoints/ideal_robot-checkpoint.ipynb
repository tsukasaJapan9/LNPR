# %%
import matplotlib.pyplot as plt
import math
import matplotlib.patches as patches
import matplotlib.animation as anm
import numpy as np
from IPython.display import HTML

# %%
class IdealRobot:
    def __init__(self, pose, color="black"):
        self.pose = pose
        self.r = 0.2
        self.color = color
        
    def draw(self, ax, elems):
        x, y, theta = self.pose
        xn = x + self.r * math.cos(theta)
        yn = y + self.r * math.sin(theta)
        elems += ax.plot([x, xn], [y, yn], color=self.color)
        c = patches.Circle(xy=(x, y), radius=self.r, color=self.color, fill=False)
        elems.append(ax.add_patch(c))

class World:
    def __init__(self, debug=False):
        self.objects = []
        self.debug = debug
    
    def append(self, obj):
        self.objects.append(obj)
    
    def draw(self):
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.set_aspect("equal")
        ax.set_xlim(-5, 5)
        ax.set_ylim(-5, 5)
        ax.set_xlabel("X", fontsize=20)
        ax.set_ylabel("Y", fontsize=20)
        
        elems = []
        
        if self.debug:
            for i in range(1000):
                self.one_step(i, elems, ax)
        else:
            self.ani = anm.FuncAnimation(fig, self.one_step, fargs=(elems, ax), frames=10, interval=1000, repeat=False)
            HTML(self.ani.to_jshtml())
        
       
    def one_step(self, i, elems, ax):
        while elems:
            elems.pop().remove()
        elems.append(ax.text(-4.4, 4,5, f"t={i}", fontsize=10))
        # for obj in self.objects:
        #     obj.draw(ax, elems)

# %%
world = World()
robot1 = IdealRobot(np.array([2, 3, math.pi / 6]).T)
robot2 = IdealRobot(np.array([-2, -1, math.pi / 1]).T)
world.append(robot1)
world.append(robot2)
world.draw()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 6
#       4 world.append(robot1)
#       5 world.append(robot2)
# ----> 6 world.draw()
#
# Cell In [23], line 39, in World.draw(self)
#      37 else:
#      38     self.ani = anm.FuncAnimation(fig, self.one_step, fargs=(elems, ax), frames=10, interval=1000, repeat=False)
# ---> 39     HTML(self.ani.to_jshtml())
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1329, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1325         path = Path(tmpdir, "temp.html")
#    1326         writer = HTMLWriter(fps=fps,
#    1327                             embed_frames=embed_frames,
#    1328                             default_mode=default_mode)
# -> 1329         self.save(str(path), writer=writer)
#    1330         self._html_representation = path.read_text()
#    1332 return self._html_representation
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1068, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1063 with mpl.rc_context({'savefig.bbox': None}), \
#    1064      writer.saving(self._fig, filename, dpi), \
#    1065      cbook._setattr_cm(self._fig.canvas,
#    1066                        _is_saving=True, manager=None):
#    1067     for anim in all_anim:
# -> 1068         anim._init_draw()  # Clear the initial frame
#    1069     frame_number = 0
#    1070     # TODO: Currently only FuncAnimation has a save_count
#    1071     #       attribute. Can we generalize this to all Animations?
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1721, in FuncAnimation._init_draw(self)
#    1713         warnings.warn(
#    1714             "Can not start iterating the frames for the initial draw. "
#    1715             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1718             "it may be exhausted due to a previous display or save."
#    1719         )
#    1720         return
# -> 1721     self._draw_frame(frame_data)
#    1722 else:
#    1723     self._drawn_artists = self._init_func()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1743, in FuncAnimation._draw_frame(self, framedata)
#    1739 self._save_seq = self._save_seq[-self.save_count:]
#    1741 # Call the func with framedata and args. If blitting is desired,
#    1742 # func needs to return a sequence of any artists that were modified.
# -> 1743 self._drawn_artists = self._func(framedata, *self._args)
#    1745 if self._blit:
#    1747     err = RuntimeError('The animation function must return a sequence '
#    1748                        'of Artist objects.')
#
# Cell In [23], line 45, in World.one_step(self, i, elems, ax)
#      43 while elems:
#      44     elems.pop().remove()
# ---> 45 elems.append(ax.text(-4.4, 4,5, f"t={i}", fontsize=10))
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/axes/_axes.py:670, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     615 @_docstring.dedent_interpd
#     616 def text(self, x, y, s, fontdict=None, **kwargs):
#     617     """
#     618     Add text to the Axes.
#     619
#    (...)
#     668         >>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
#     669     """
# --> 670     effective_kwargs = {
#     671         'verticalalignment': 'baseline',
#     672         'horizontalalignment': 'left',
#     673         'transform': self.transData,
#     674         'clip_on': False,
#     675         **(fontdict if fontdict is not None else {}),
#     676         **kwargs,
#     677     }
#     678     t = mtext.Text(x, y, text=s, **effective_kwargs)
#     679     t.set_clip_path(self.patch)
#
# TypeError: 'str' object is not a mapping
# Error in callback <function _draw_all_if_interactive at 0x7f754138ea60> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/figure.py:3081, in Figure.draw(self, renderer)
#    3078 finally:
#    3079     self.stale = False
# -> 3081 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/backend_bases.py:1230, in Event._process(self)
#    1228 def _process(self):
#    1229     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1230     self.canvas.callbacks.process(self.name, self)
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:312, in CallbackRegistry.process(self, s, *args, **kwargs)
#     310 except Exception as exc:
#     311     if self.exception_handler is not None:
# --> 312         self.exception_handler(exc)
#     313     else:
#     314         raise
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:307, in CallbackRegistry.process(self, s, *args, **kwargs)
#     305 if func is not None:
#     306     try:
# --> 307         func(*args, **kwargs)
#     308     # this does not capture KeyboardInterrupt, SystemExit,
#     309     # and GeneratorExit
#     310     except Exception as exc:
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:899, in Animation._start(self, *args)
#     896 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     898 # Now do any initial draw
# --> 899 self._init_draw()
#     901 # Add our callback for stepping the animation and
#     902 # actually start the event_source.
#     903 self.event_source.add_callback(self._step)
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1721, in FuncAnimation._init_draw(self)
#    1713         warnings.warn(
#    1714             "Can not start iterating the frames for the initial draw. "
#    1715             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1718             "it may be exhausted due to a previous display or save."
#    1719         )
#    1720         return
# -> 1721     self._draw_frame(frame_data)
#    1722 else:
#    1723     self._drawn_artists = self._init_func()
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/animation.py:1743, in FuncAnimation._draw_frame(self, framedata)
#    1739 self._save_seq = self._save_seq[-self.save_count:]
#    1741 # Call the func with framedata and args. If blitting is desired,
#    1742 # func needs to return a sequence of any artists that were modified.
# -> 1743 self._drawn_artists = self._func(framedata, *self._args)
#    1745 if self._blit:
#    1747     err = RuntimeError('The animation function must return a sequence '
#    1748                        'of Artist objects.')
#
# Cell In [23], line 45, in World.one_step(self, i, elems, ax)
#      43 while elems:
#      44     elems.pop().remove()
# ---> 45 elems.append(ax.text(-4.4, 4,5, f"t={i}", fontsize=10))
#
# File ~/.pyenv/versions/3.9.14/lib/python3.9/site-packages/matplotlib/axes/_axes.py:670, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     615 @_docstring.dedent_interpd
#     616 def text(self, x, y, s, fontdict=None, **kwargs):
#     617     """
#     618     Add text to the Axes.
#     619
#    (...)
#     668         >>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
#     669     """
# --> 670     effective_kwargs = {
#     671         'verticalalignment': 'baseline',
#     672         'horizontalalignment': 'left',
#     673         'transform': self.transData,
#     674         'clip_on': False,
#     675         **(fontdict if fontdict is not None else {}),
#     676         **kwargs,
#     677     }
#     678     t = mtext.Text(x, y, text=s, **effective_kwargs)
#     679     t.set_clip_path(self.patch)
#
# TypeError: 'str' object is not a mapping
